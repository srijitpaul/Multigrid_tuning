# %%
import numpy as np
import sys
import itertools
import operator
import functools
import os
import subprocess

# %%
def primes(n):
    primfac = []
    d = 2
    while d*d <= n:
        while (n % d) == 0:
            primfac.append(d)  # supposing you want multiple factors repeated
            n //= d
        d += 1
    if n > 1:
       primfac.append(n)
    return primfac
def sorted_k_partitions(seq, k):
    """Returns a list of all unique k-partitions of `seq`.

    Each partition is a list of parts, and each part is a tuple.

    The parts in each individual partition will be sorted in shortlex
    order (i.e., by length first, then lexicographically).

    The overall list of partitions will then be sorted by the length
    of their first part, the length of their second part, ...,
    the length of their last part, and then lexicographically.
    """
    n = len(seq)
    groups = []  # a list of lists, currently empty

    def generate_partitions(i):
        if i >= n:
            yield list(set(list(map(tuple, groups))))
        else:
            if n - i > k - len(groups):
                for group in groups:
                    group.append(seq[i])
                    yield from generate_partitions(i + 1)
                    group.pop()

            if len(groups) < k:
                groups.append([seq[i]])
                yield from generate_partitions(i + 1)
                groups.pop()

    result = generate_partitions(0)
    # Sort the parts in each partition in shortlex order
    result = [sorted(ps, key = lambda p: (len(p), p)) for ps in result]
    # Sort partitions by the length of each part, then lexicographically.
    result = sorted(result, key = lambda ps: (*map(len, ps), ps))
    for ps in result:
        if len(ps)==1:
            ps.append(*ps)
            

    result = list(set(tuple(x) for x in result))
    
    return result

# %%
#Lattice size patameters
L = 48
T = 96
cores_per_node = 24

# %%
prime_factors_L = primes(L)
prime_factors_T = primes(T)
num_prime_factors_L = len(prime_factors_L)
num_prime_factors_T = len(prime_factors_T)
print(num_prime_factors_L)
print(num_prime_factors_T)
# Out:
# 5
# 6

# %%
#We investigate first the possible sizes of the Coarsest Grid
#For that we start with any smallest combination fo prime numbers >= 4.
for nL in range(2,num_prime_factors_L-1):
    for nT in range(2,num_prime_factors_T-1):
        if nL<=nT:
            num_L_coarse = list(set(list(itertools.combinations((prime_factors_L),nL))))
            num_T_coarse = list(set(list(itertools.combinations((prime_factors_T),nT))))
            
            coarse_L = [functools.reduce(operator.mul, item, 1) for item in num_L_coarse]
            coarse_T = [functools.reduce(operator.mul, item, 1) for item in num_T_coarse]
            coarse_lat = itertools.product(coarse_L,coarse_T)
            coarse_lat_2 = itertools.product(coarse_L,coarse_T)
            #print(nL, coarse_L)
            #print(nT, coarse_T)
            #for core in coarse_lat_2:
               # if core[0]<=core[1]:
                    #print("Possible number of cores:", core[0]*core[0]*core[0]*core[1])
            for i in coarse_lat:
                if i[0]<=i[1]:
                    L_coarse = i[0]
                    T_coarse = i[1]
                    print("Possible number of cores:", i[0]*i[0]*i[0]*i[1])
                    print("Making directory:{}c{}".format(L_coarse,T_coarse))
                    path = "{}c{}".format(L_coarse,T_coarse)
                    os.makedirs(path, exist_ok=True)
                    #print("Prime factors of L for deciding the block sizes: {}".format(primes(L/L_coarse)))
                    #print("Prime factors of T for deciding the block sizes: {}".format(primes(T/T_coarse)))
                    prime_fac_partition_L = primes(L/L_coarse)
                    prime_fac_partition_T = primes(T/T_coarse)
                    filename_counter = 1
                    for L_partitions in sorted_k_partitions(prime_fac_partition_L,2):
                        for T_partitions in sorted_k_partitions(prime_fac_partition_T,2):
                            L_blocks = [functools.reduce(operator.mul, item, 1) for item in L_partitions]
                            T_blocks = [functools.reduce(operator.mul, item, 1) for item in T_partitions]
                            #print(L_blocks, T_blocks)
                            block_size =[list(zip(L_blocks, p)) for p in itertools.permutations(T_blocks)]
                            if functools.reduce(operator.mul,block_size[0][0],1)<functools.reduce(operator.mul,block_size[0][1],1):
                                dummy = block_size[0][0] 
                                block_size[0][0] = block_size[0][1]
                                block_size[0][1] = dummy
                            if functools.reduce(operator.mul,block_size[1][0],1)<functools.reduce(operator.mul,block_size[1][1],1):
                                dummy = block_size[1][0]
                                block_size[1][0] = block_size[1][1]
                                block_size[1][1] = dummy
                            block_size = list(set(tuple(x) for x in block_size))
                            #print("Block size length:",len(block_size))
                            #print("Block_1 size:",block_size[0][1])
                            for j in range(1,len(block_size)+1):
                                print("Block_0 size :", block_size[j-1][0])
                                print("Block_1 size :", block_size[j-1][1])
                                print("This is filename: {}.qlua".format(filename_counter))
                                bashcall = "./make_qlua.sh {} {} {} {} {} {}".format(path, filename_counter, block_size[j-1][0][0], block_size[j-1][0][1], block_size[j-1][1][0], block_size[j-1][1][1])
                                print(bashcall)
                                subprocess.call(bashcall, shell=True)
                                runfile_counter = "{}_{}_{}.sh".format(filename_counter,path,i[0]*i[0]*i[0]*i[1])
                                num_nodes = np.int(np.ceil((i[0]*i[0]*i[0]*i[1])/cores_per_node))
                                runbashcall = "./make_edison_run.sh {} {} {} {}".format(path, filename_counter, num_nodes,i[0]*i[0]*i[0]*i[1])
                                subprocess.call(runbashcall, shell=True)
                                filename_counter = filename_counter + 1
                                print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
                            
                            
                            
                            
                    
            print("----------------")
            print("----------------")
# Out:
# Possible number of cores: 1296
# Making directory:6c6
# Block_0 size : (4, 4)
# Block_1 size : (2, 4)
# This is filename: 1.qlua
# ./make_qlua.sh 6c6 1 4 4 2 4
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (2, 8)
# Block_1 size : (4, 2)
# This is filename: 2.qlua
# ./make_qlua.sh 6c6 2 2 8 4 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (4, 8)
# Block_1 size : (2, 2)
# This is filename: 3.qlua
# ./make_qlua.sh 6c6 3 4 8 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Possible number of cores: 384
# Making directory:4c6
# Block_0 size : (4, 4)
# Block_1 size : (3.0, 4)
# This is filename: 1.qlua
# ./make_qlua.sh 4c6 1 4 4 3.0 4
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (3.0, 8)
# Block_1 size : (4, 2)
# This is filename: 2.qlua
# ./make_qlua.sh 4c6 2 3.0 8 4 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (4, 8)
# Block_1 size : (3.0, 2)
# This is filename: 3.qlua
# ./make_qlua.sh 4c6 3 4 8 3.0 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (6.0, 4)
# Block_1 size : (2, 4)
# This is filename: 4.qlua
# ./make_qlua.sh 4c6 4 6.0 4 2 4
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (6.0, 8)
# Block_1 size : (2, 2)
# This is filename: 5.qlua
# ./make_qlua.sh 4c6 5 6.0 8 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (2, 8)
# Block_1 size : (6.0, 2)
# This is filename: 6.qlua
# ./make_qlua.sh 4c6 6 2 8 6.0 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Possible number of cores: 256
# Making directory:4c4
# Block_0 size : (4, 12.0)
# Block_1 size : (3.0, 2)
# This is filename: 1.qlua
# ./make_qlua.sh 4c4 1 4 12.0 3.0 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (3.0, 12.0)
# Block_1 size : (4, 2)
# This is filename: 2.qlua
# ./make_qlua.sh 4c4 2 3.0 12.0 4 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (3.0, 6.0)
# Block_1 size : (4, 4)
# This is filename: 3.qlua
# ./make_qlua.sh 4c4 3 3.0 6.0 4 4
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (4, 6.0)
# Block_1 size : (3.0, 4)
# This is filename: 4.qlua
# ./make_qlua.sh 4c4 4 4 6.0 3.0 4
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (3.0, 8)
# Block_1 size : (4, 3.0)
# This is filename: 5.qlua
# ./make_qlua.sh 4c4 5 3.0 8 4 3.0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (4, 8)
# Block_1 size : (3.0, 3.0)
# This is filename: 6.qlua
# ./make_qlua.sh 4c4 6 4 8 3.0 3.0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (2, 12.0)
# Block_1 size : (6.0, 2)
# This is filename: 7.qlua
# ./make_qlua.sh 4c4 7 2 12.0 6.0 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (6.0, 12.0)
# Block_1 size : (2, 2)
# This is filename: 8.qlua
# ./make_qlua.sh 4c4 8 6.0 12.0 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (6.0, 6.0)
# Block_1 size : (2, 4)
# This is filename: 9.qlua
# ./make_qlua.sh 4c4 9 6.0 6.0 2 4
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (6.0, 4)
# Block_1 size : (2, 6.0)
# This is filename: 10.qlua
# ./make_qlua.sh 4c4 10 6.0 4 2 6.0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (6.0, 3.0)
# Block_1 size : (2, 8)
# This is filename: 11.qlua
# ./make_qlua.sh 4c4 11 6.0 3.0 2 8
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (6.0, 8)
# Block_1 size : (2, 3.0)
# This is filename: 12.qlua
# ./make_qlua.sh 4c4 12 6.0 8 2 3.0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ----------------
# ----------------
# Possible number of cores: 1728
# Making directory:6c8
# Block_0 size : (4, 4)
# Block_1 size : (2, 3.0)
# This is filename: 1.qlua
# ./make_qlua.sh 6c8 1 4 4 2 3.0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (4, 3.0)
# Block_1 size : (2, 4)
# This is filename: 2.qlua
# ./make_qlua.sh 6c8 2 4 3.0 2 4
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (4, 6.0)
# Block_1 size : (2, 2)
# This is filename: 3.qlua
# ./make_qlua.sh 6c8 3 4 6.0 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (2, 6.0)
# Block_1 size : (4, 2)
# This is filename: 4.qlua
# ./make_qlua.sh 6c8 4 2 6.0 4 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Possible number of cores: 2592
# Making directory:6c12
# Block_0 size : (4, 4)
# Block_1 size : (2, 2)
# This is filename: 1.qlua
# ./make_qlua.sh 6c12 1 4 4 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (2, 4)
# Block_1 size : (4, 2)
# This is filename: 2.qlua
# ./make_qlua.sh 6c12 2 2 4 4 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Possible number of cores: 512
# Making directory:4c8
# Block_0 size : (3.0, 4)
# Block_1 size : (4, 3.0)
# This is filename: 1.qlua
# ./make_qlua.sh 4c8 1 3.0 4 4 3.0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (4, 4)
# Block_1 size : (3.0, 3.0)
# This is filename: 2.qlua
# ./make_qlua.sh 4c8 2 4 4 3.0 3.0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (3.0, 6.0)
# Block_1 size : (4, 2)
# This is filename: 3.qlua
# ./make_qlua.sh 4c8 3 3.0 6.0 4 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (4, 6.0)
# Block_1 size : (3.0, 2)
# This is filename: 4.qlua
# ./make_qlua.sh 4c8 4 4 6.0 3.0 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (6.0, 3.0)
# Block_1 size : (2, 4)
# This is filename: 5.qlua
# ./make_qlua.sh 4c8 5 6.0 3.0 2 4
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (6.0, 4)
# Block_1 size : (2, 3.0)
# This is filename: 6.qlua
# ./make_qlua.sh 4c8 6 6.0 4 2 3.0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (2, 6.0)
# Block_1 size : (6.0, 2)
# This is filename: 7.qlua
# ./make_qlua.sh 4c8 7 2 6.0 6.0 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (6.0, 6.0)
# Block_1 size : (2, 2)
# This is filename: 8.qlua
# ./make_qlua.sh 4c8 8 6.0 6.0 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Possible number of cores: 768
# Making directory:4c12
# Block_0 size : (4, 4)
# Block_1 size : (3.0, 2)
# This is filename: 1.qlua
# ./make_qlua.sh 4c12 1 4 4 3.0 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (3.0, 4)
# Block_1 size : (4, 2)
# This is filename: 2.qlua
# ./make_qlua.sh 4c12 2 3.0 4 4 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (6.0, 2)
# Block_1 size : (2, 4)
# This is filename: 3.qlua
# ./make_qlua.sh 4c12 3 6.0 2 2 4
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (6.0, 4)
# Block_1 size : (2, 2)
# This is filename: 4.qlua
# ./make_qlua.sh 4c12 4 6.0 4 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ----------------
# ----------------
# Possible number of cores: 5184
# Making directory:6c24
# Block_0 size : (4, 2)
# Block_1 size : (2, 2)
# This is filename: 1.qlua
# ./make_qlua.sh 6c24 1 4 2 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Possible number of cores: 3456
# Making directory:6c16
# Block_0 size : (4, 3.0)
# Block_1 size : (2, 2)
# This is filename: 1.qlua
# ./make_qlua.sh 6c16 1 4 3.0 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (4, 2)
# Block_1 size : (2, 3.0)
# This is filename: 2.qlua
# ./make_qlua.sh 6c16 2 4 2 2 3.0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Possible number of cores: 1536
# Making directory:4c24
# Block_0 size : (4, 2)
# Block_1 size : (3.0, 2)
# This is filename: 1.qlua
# ./make_qlua.sh 4c24 1 4 2 3.0 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (6.0, 2)
# Block_1 size : (2, 2)
# This is filename: 2.qlua
# ./make_qlua.sh 4c24 2 6.0 2 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Possible number of cores: 1024
# Making directory:4c16
# Block_0 size : (3.0, 3.0)
# Block_1 size : (4, 2)
# This is filename: 1.qlua
# ./make_qlua.sh 4c16 1 3.0 3.0 4 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (4, 3.0)
# Block_1 size : (3.0, 2)
# This is filename: 2.qlua
# ./make_qlua.sh 4c16 2 4 3.0 3.0 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (6.0, 2)
# Block_1 size : (2, 3.0)
# This is filename: 3.qlua
# ./make_qlua.sh 4c16 3 6.0 2 2 3.0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (6.0, 3.0)
# Block_1 size : (2, 2)
# This is filename: 4.qlua
# ./make_qlua.sh 4c16 4 6.0 3.0 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ----------------
# ----------------
# Possible number of cores: 4096
# Making directory:8c8
# Block_0 size : (3.0, 4)
# Block_1 size : (2, 3.0)
# This is filename: 1.qlua
# ./make_qlua.sh 8c8 1 3.0 4 2 3.0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (3.0, 3.0)
# Block_1 size : (2, 4)
# This is filename: 2.qlua
# ./make_qlua.sh 8c8 2 3.0 3.0 2 4
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (2, 6.0)
# Block_1 size : (3.0, 2)
# This is filename: 3.qlua
# ./make_qlua.sh 8c8 3 2 6.0 3.0 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (3.0, 6.0)
# Block_1 size : (2, 2)
# This is filename: 4.qlua
# ./make_qlua.sh 8c8 4 3.0 6.0 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Possible number of cores: 6144
# Making directory:8c12
# Block_0 size : (3.0, 4)
# Block_1 size : (2, 2)
# This is filename: 1.qlua
# ./make_qlua.sh 8c12 1 3.0 4 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (2, 4)
# Block_1 size : (3.0, 2)
# This is filename: 2.qlua
# ./make_qlua.sh 8c12 2 2 4 3.0 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Possible number of cores: 20736
# Making directory:12c12
# Block_0 size : (2, 4)
# Block_1 size : (2, 2)
# This is filename: 1.qlua
# ./make_qlua.sh 12c12 1 2 4 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ----------------
# ----------------
# Possible number of cores: 12288
# Making directory:8c24
# Block_0 size : (3.0, 2)
# Block_1 size : (2, 2)
# This is filename: 1.qlua
# ./make_qlua.sh 8c24 1 3.0 2 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Possible number of cores: 8192
# Making directory:8c16
# Block_0 size : (2, 3.0)
# Block_1 size : (3.0, 2)
# This is filename: 1.qlua
# ./make_qlua.sh 8c16 1 2 3.0 3.0 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Block_0 size : (3.0, 3.0)
# Block_1 size : (2, 2)
# This is filename: 2.qlua
# ./make_qlua.sh 8c16 2 3.0 3.0 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Possible number of cores: 41472
# Making directory:12c24
# Block_0 size : (2, 2)
# Block_1 size : (2, 2)
# This is filename: 1.qlua
# ./make_qlua.sh 12c24 1 2 2 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Possible number of cores: 27648
# Making directory:12c16
# Block_0 size : (2, 3.0)
# Block_1 size : (2, 2)
# This is filename: 1.qlua
# ./make_qlua.sh 12c16 1 2 3.0 2 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ----------------
# ----------------
